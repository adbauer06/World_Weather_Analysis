# %%
# Import the dependencies.
import pandas as pd
import numpy as np

#Import the citipy module
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city to our coordinates
# Create a cities list that will contain all unique cities from our coordinates
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count
len(cities)
# Out:
# 758

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create and initialize counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ponta delgada
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | ye
# City not found. Skipping...
# Processing Record 5 of Set 1 | silale
# Processing Record 6 of Set 1 | luderitz
# Processing Record 7 of Set 1 | deniliquin
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | lavrentiya
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | krasnoselkup
# Processing Record 13 of Set 1 | dubrovnik
# Processing Record 14 of Set 1 | nemuro
# Processing Record 15 of Set 1 | saint-augustin
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | caravelas
# Processing Record 18 of Set 1 | krasnaya gorbatka
# Processing Record 19 of Set 1 | esperance
# Processing Record 20 of Set 1 | ostersund
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | mokhsogollokh
# Processing Record 24 of Set 1 | milton
# Processing Record 25 of Set 1 | sola
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | garowe
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | lompoc
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | chokurdakh
# Processing Record 33 of Set 1 | narasannapeta
# Processing Record 34 of Set 1 | san policarpo
# Processing Record 35 of Set 1 | urumqi
# Processing Record 36 of Set 1 | thompson
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | natal
# Processing Record 39 of Set 1 | byron bay
# Processing Record 40 of Set 1 | kasane
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | nichinan
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | matay
# Processing Record 46 of Set 1 | snyder
# Processing Record 47 of Set 1 | huntsville
# Processing Record 48 of Set 1 | lagos
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | adrar
# Processing Record 1 of Set 2 | vinh long
# Processing Record 2 of Set 2 | lampa
# Processing Record 3 of Set 2 | vila franca do campo
# Processing Record 4 of Set 2 | marienburg
# Processing Record 5 of Set 2 | hami
# Processing Record 6 of Set 2 | oranjestad
# Processing Record 7 of Set 2 | ust-donetskiy
# Processing Record 8 of Set 2 | chateauroux
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | saint-philippe
# Processing Record 11 of Set 2 | husavik
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | hakkari
# Processing Record 15 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 2 | namibe
# Processing Record 17 of Set 2 | san patricio
# Processing Record 18 of Set 2 | vardo
# Processing Record 19 of Set 2 | nioki
# Processing Record 20 of Set 2 | erbach
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | sorland
# Processing Record 24 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | castro
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | rio muerto
# Processing Record 30 of Set 2 | bluff
# Processing Record 31 of Set 2 | huarmey
# Processing Record 32 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 2 | yarada
# Processing Record 34 of Set 2 | shimoda
# Processing Record 35 of Set 2 | bichura
# Processing Record 36 of Set 2 | dikson
# Processing Record 37 of Set 2 | sao jose da coroa grande
# Processing Record 38 of Set 2 | atuona
# Processing Record 39 of Set 2 | leh
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | el estor
# Processing Record 42 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 2 | pisco
# Processing Record 44 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 2 | ndola
# Processing Record 46 of Set 2 | la asuncion
# Processing Record 47 of Set 2 | biu
# Processing Record 48 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 2 | langxiang
# Processing Record 50 of Set 2 | kasongo-lunda
# Processing Record 1 of Set 3 | ferrol
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | fethiye
# Processing Record 4 of Set 3 | stokmarknes
# Processing Record 5 of Set 3 | lundamo
# Processing Record 6 of Set 3 | inuvik
# Processing Record 7 of Set 3 | portland
# Processing Record 8 of Set 3 | mount gambier
# Processing Record 9 of Set 3 | churapcha
# Processing Record 10 of Set 3 | vulcanesti
# Processing Record 11 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | mahebourg
# Processing Record 14 of Set 3 | port macquarie
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | tezu
# Processing Record 17 of Set 3 | naze
# Processing Record 18 of Set 3 | vaini
# Processing Record 19 of Set 3 | vila velha
# Processing Record 20 of Set 3 | qinzhou
# Processing Record 21 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 22 of Set 3 | cabo san lucas
# Processing Record 23 of Set 3 | kahului
# Processing Record 24 of Set 3 | tuktoyaktuk
# Processing Record 25 of Set 3 | fairbanks
# Processing Record 26 of Set 3 | tual
# Processing Record 27 of Set 3 | ligayan
# Processing Record 28 of Set 3 | nanortalik
# Processing Record 29 of Set 3 | college
# Processing Record 30 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 3 | niamey
# Processing Record 32 of Set 3 | naberera
# Processing Record 33 of Set 3 | port-de-paix
# City not found. Skipping...
# Processing Record 34 of Set 3 | katsuura
# Processing Record 35 of Set 3 | sibiti
# Processing Record 36 of Set 3 | zhicheng
# Processing Record 37 of Set 3 | kontagora
# Processing Record 38 of Set 3 | oranienburg
# Processing Record 39 of Set 3 | namatanai
# Processing Record 40 of Set 3 | coquimbo
# Processing Record 41 of Set 3 | barrow
# Processing Record 42 of Set 3 | awbari
# Processing Record 43 of Set 3 | lahijan
# Processing Record 44 of Set 3 | puerto baquerizo moreno
# Processing Record 45 of Set 3 | ca mau
# Processing Record 46 of Set 3 | cidreira
# Processing Record 47 of Set 3 | sompeta
# Processing Record 48 of Set 3 | cockburn town
# Processing Record 49 of Set 3 | port hardy
# Processing Record 50 of Set 3 | guerrero negro
# Processing Record 1 of Set 4 | clyde river
# Processing Record 2 of Set 4 | cayenne
# Processing Record 3 of Set 4 | medea
# Processing Record 4 of Set 4 | hobyo
# Processing Record 5 of Set 4 | te anau
# Processing Record 6 of Set 4 | saint-paul
# Processing Record 7 of Set 4 | tasiilaq
# Processing Record 8 of Set 4 | punta arenas
# Processing Record 9 of Set 4 | ribeira grande
# Processing Record 10 of Set 4 | khatanga
# Processing Record 11 of Set 4 | begun
# Processing Record 12 of Set 4 | chernyshevskiy
# Processing Record 13 of Set 4 | kodiak
# Processing Record 14 of Set 4 | tinsukia
# Processing Record 15 of Set 4 | camacha
# Processing Record 16 of Set 4 | zhezkazgan
# Processing Record 17 of Set 4 | isangel
# Processing Record 18 of Set 4 | tuatapere
# Processing Record 19 of Set 4 | kaoma
# Processing Record 20 of Set 4 | flinders
# Processing Record 21 of Set 4 | meinung
# City not found. Skipping...
# Processing Record 22 of Set 4 | saskylakh
# Processing Record 23 of Set 4 | sovetskiy
# Processing Record 24 of Set 4 | bonoua
# Processing Record 25 of Set 4 | bandarbeyla
# Processing Record 26 of Set 4 | changli
# Processing Record 27 of Set 4 | kavieng
# Processing Record 28 of Set 4 | sao joao da barra
# Processing Record 29 of Set 4 | nivala
# Processing Record 30 of Set 4 | havoysund
# Processing Record 31 of Set 4 | bilibino
# Processing Record 32 of Set 4 | luganville
# Processing Record 33 of Set 4 | narsaq
# Processing Record 34 of Set 4 | kerema
# Processing Record 35 of Set 4 | victoria
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | kaitangata
# Processing Record 38 of Set 4 | comodoro rivadavia
# Processing Record 39 of Set 4 | riachao das neves
# Processing Record 40 of Set 4 | staryy nadym
# Processing Record 41 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 4 | ponta do sol
# Processing Record 43 of Set 4 | hithadhoo
# Processing Record 44 of Set 4 | bermejo
# Processing Record 45 of Set 4 | urucara
# Processing Record 46 of Set 4 | little current
# Processing Record 47 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 4 | ucluelet
# Processing Record 49 of Set 4 | faya
# Processing Record 50 of Set 4 | maykain
# City not found. Skipping...
# Processing Record 1 of Set 5 | ponte de sor
# Processing Record 2 of Set 5 | okhotsk
# Processing Record 3 of Set 5 | magalia
# Processing Record 4 of Set 5 | buraydah
# Processing Record 5 of Set 5 | iguape
# Processing Record 6 of Set 5 | broome
# Processing Record 7 of Set 5 | mar del plata
# Processing Record 8 of Set 5 | galdar
# Processing Record 9 of Set 5 | keetmanshoop
# Processing Record 10 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 11 of Set 5 | la ronge
# Processing Record 12 of Set 5 | burica
# City not found. Skipping...
# Processing Record 13 of Set 5 | mweka
# Processing Record 14 of Set 5 | aldama
# Processing Record 15 of Set 5 | progreso
# Processing Record 16 of Set 5 | los llanos de aridane
# Processing Record 17 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 18 of Set 5 | den helder
# Processing Record 19 of Set 5 | carutapera
# Processing Record 20 of Set 5 | bahia honda
# Processing Record 21 of Set 5 | westport
# Processing Record 22 of Set 5 | mosquera
# Processing Record 23 of Set 5 | puerto ayora
# Processing Record 24 of Set 5 | ilulissat
# Processing Record 25 of Set 5 | avenal
# Processing Record 26 of Set 5 | souillac
# Processing Record 27 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 5 | bengkulu
# Processing Record 29 of Set 5 | airai
# Processing Record 30 of Set 5 | katobu
# Processing Record 31 of Set 5 | killybegs
# Processing Record 32 of Set 5 | qaanaaq
# Processing Record 33 of Set 5 | hirado
# Processing Record 34 of Set 5 | paka
# Processing Record 35 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 5 | klaksvik
# Processing Record 37 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 38 of Set 5 | burley
# Processing Record 39 of Set 5 | trairi
# Processing Record 40 of Set 5 | otane
# Processing Record 41 of Set 5 | yar-sale
# Processing Record 42 of Set 5 | poum
# Processing Record 43 of Set 5 | yeppoon
# Processing Record 44 of Set 5 | ust-kuyga
# Processing Record 45 of Set 5 | hamilton
# Processing Record 46 of Set 5 | ancud
# Processing Record 47 of Set 5 | bethel
# Processing Record 48 of Set 5 | bambous virieux
# Processing Record 49 of Set 5 | inzer
# Processing Record 50 of Set 5 | bilma
# Processing Record 1 of Set 6 | buala
# Processing Record 2 of Set 6 | norman wells
# Processing Record 3 of Set 6 | port blair
# Processing Record 4 of Set 6 | batagay-alyta
# Processing Record 5 of Set 6 | doha
# Processing Record 6 of Set 6 | monroe
# Processing Record 7 of Set 6 | zhaotong
# Processing Record 8 of Set 6 | kostomuksha
# Processing Record 9 of Set 6 | hailun
# Processing Record 10 of Set 6 | safaga
# Processing Record 11 of Set 6 | saquena
# Processing Record 12 of Set 6 | wajir
# Processing Record 13 of Set 6 | lazaro cardenas
# Processing Record 14 of Set 6 | visnes
# Processing Record 15 of Set 6 | harper
# Processing Record 16 of Set 6 | anadyr
# Processing Record 17 of Set 6 | puerto escondido
# Processing Record 18 of Set 6 | santo antonio do ica
# Processing Record 19 of Set 6 | longyearbyen
# Processing Record 20 of Set 6 | sioux lookout
# Processing Record 21 of Set 6 | mount isa
# Processing Record 22 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 6 | port lincoln
# Processing Record 24 of Set 6 | mvuma
# Processing Record 25 of Set 6 | lorengau
# Processing Record 26 of Set 6 | barabai
# Processing Record 27 of Set 6 | launceston
# Processing Record 28 of Set 6 | tura
# Processing Record 29 of Set 6 | aichach
# Processing Record 30 of Set 6 | beringovskiy
# Processing Record 31 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 6 | codrington
# Processing Record 33 of Set 6 | dingle
# Processing Record 34 of Set 6 | mujiayingzi
# Processing Record 35 of Set 6 | komsomolskiy
# Processing Record 36 of Set 6 | kysyl-syr
# Processing Record 37 of Set 6 | shikohabad
# Processing Record 38 of Set 6 | ilhabela
# Processing Record 39 of Set 6 | paita
# Processing Record 40 of Set 6 | leningradskiy
# Processing Record 41 of Set 6 | bulungu
# Processing Record 42 of Set 6 | port hedland
# Processing Record 43 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 6 | altay
# Processing Record 45 of Set 6 | macapa
# Processing Record 46 of Set 6 | mamakan
# Processing Record 47 of Set 6 | chiredzi
# Processing Record 48 of Set 6 | dhidhdhoo
# Processing Record 49 of Set 6 | jacareacanga
# Processing Record 50 of Set 6 | khor
# Processing Record 1 of Set 7 | virginia beach
# Processing Record 2 of Set 7 | at-bashi
# Processing Record 3 of Set 7 | araguaina
# Processing Record 4 of Set 7 | saint george
# Processing Record 5 of Set 7 | alofi
# Processing Record 6 of Set 7 | severo-kurilsk
# Processing Record 7 of Set 7 | acarau
# Processing Record 8 of Set 7 | tiruvottiyur
# City not found. Skipping...
# Processing Record 9 of Set 7 | half moon bay
# Processing Record 10 of Set 7 | severo-yeniseyskiy
# Processing Record 11 of Set 7 | geraldton
# Processing Record 12 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 7 | turukhansk
# Processing Record 14 of Set 7 | odienne
# Processing Record 15 of Set 7 | diffa
# Processing Record 16 of Set 7 | rocha
# Processing Record 17 of Set 7 | peranamallur
# Processing Record 18 of Set 7 | chissamba
# Processing Record 19 of Set 7 | chulumani
# Processing Record 20 of Set 7 | balabac
# Processing Record 21 of Set 7 | sinnamary
# Processing Record 22 of Set 7 | zaoyang
# Processing Record 23 of Set 7 | yaan
# Processing Record 24 of Set 7 | faanui
# Processing Record 25 of Set 7 | maneadero
# Processing Record 26 of Set 7 | egvekinot
# Processing Record 27 of Set 7 | bouca
# Processing Record 28 of Set 7 | yafran
# Processing Record 29 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 7 | cherskiy
# Processing Record 31 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 32 of Set 7 | kununurra
# Processing Record 33 of Set 7 | quatre cocos
# Processing Record 34 of Set 7 | nha trang
# Processing Record 35 of Set 7 | ellensburg
# Processing Record 36 of Set 7 | kita
# Processing Record 37 of Set 7 | farafenni
# Processing Record 38 of Set 7 | pak phanang
# Processing Record 39 of Set 7 | sandwick
# Processing Record 40 of Set 7 | kushima
# Processing Record 41 of Set 7 | fortuna
# Processing Record 42 of Set 7 | peniche
# Processing Record 43 of Set 7 | san quintin
# Processing Record 44 of Set 7 | sur
# Processing Record 45 of Set 7 | ust-maya
# Processing Record 46 of Set 7 | hasaki
# Processing Record 47 of Set 7 | ahipara
# Processing Record 48 of Set 7 | roros
# Processing Record 49 of Set 7 | mongomo
# Processing Record 50 of Set 7 | saint-francois
# Processing Record 1 of Set 8 | abashiri
# Processing Record 2 of Set 8 | chekhov
# Processing Record 3 of Set 8 | poya
# Processing Record 4 of Set 8 | stromness
# Processing Record 5 of Set 8 | adelaide
# Processing Record 6 of Set 8 | honningsvag
# Processing Record 7 of Set 8 | waingapu
# Processing Record 8 of Set 8 | shamli
# Processing Record 9 of Set 8 | silute
# Processing Record 10 of Set 8 | torbay
# Processing Record 11 of Set 8 | palafrugell
# Processing Record 12 of Set 8 | rimbey
# Processing Record 13 of Set 8 | naron
# Processing Record 14 of Set 8 | laguna
# Processing Record 15 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 8 | havelock
# Processing Record 17 of Set 8 | lingen
# Processing Record 18 of Set 8 | weihe
# Processing Record 19 of Set 8 | tautira
# Processing Record 20 of Set 8 | chodavaram
# Processing Record 21 of Set 8 | haines junction
# Processing Record 22 of Set 8 | phuntsholing
# Processing Record 23 of Set 8 | kieta
# Processing Record 24 of Set 8 | asau
# Processing Record 25 of Set 8 | old road
# City not found. Skipping...
# Processing Record 26 of Set 8 | arman
# Processing Record 27 of Set 8 | nargana
# Processing Record 28 of Set 8 | mapiripan
# Processing Record 29 of Set 8 | scarborough
# Processing Record 30 of Set 8 | kutum
# Processing Record 31 of Set 8 | baykit
# Processing Record 32 of Set 8 | timmins
# Processing Record 33 of Set 8 | sitka
# Processing Record 34 of Set 8 | rio gallegos
# Processing Record 35 of Set 8 | lakselv
# Processing Record 36 of Set 8 | enshi
# Processing Record 37 of Set 8 | kindu
# Processing Record 38 of Set 8 | penzance
# Processing Record 39 of Set 8 | karla
# Processing Record 40 of Set 8 | araouane
# Processing Record 41 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 42 of Set 8 | liverpool
# Processing Record 43 of Set 8 | rawson
# Processing Record 44 of Set 8 | muisne
# Processing Record 45 of Set 8 | chesma
# Processing Record 46 of Set 8 | zhigalovo
# Processing Record 47 of Set 8 | dovers
# Processing Record 48 of Set 8 | sao geraldo do araguaia
# Processing Record 49 of Set 8 | tutoia
# Processing Record 50 of Set 8 | qaqortoq
# Processing Record 1 of Set 9 | flin flon
# Processing Record 2 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 3 of Set 9 | huron
# Processing Record 4 of Set 9 | kalmunai
# Processing Record 5 of Set 9 | arraial do cabo
# Processing Record 6 of Set 9 | tarakan
# Processing Record 7 of Set 9 | meulaboh
# Processing Record 8 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 9 | karratha
# Processing Record 10 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 9 | kormilovka
# Processing Record 12 of Set 9 | boysun
# Processing Record 13 of Set 9 | zhigansk
# Processing Record 14 of Set 9 | oakdale
# Processing Record 15 of Set 9 | calvia
# Processing Record 16 of Set 9 | findlay
# Processing Record 17 of Set 9 | zittau
# Processing Record 18 of Set 9 | viedma
# Processing Record 19 of Set 9 | maicao
# Processing Record 20 of Set 9 | petersburg
# Processing Record 21 of Set 9 | mareeba
# Processing Record 22 of Set 9 | tilichiki
# Processing Record 23 of Set 9 | potiskum
# Processing Record 24 of Set 9 | ust-nera
# Processing Record 25 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 9 | pingdingshan
# Processing Record 28 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 9 | hovd
# Processing Record 30 of Set 9 | kenitra
# Processing Record 31 of Set 9 | houma
# Processing Record 32 of Set 9 | novyy buh
# Processing Record 33 of Set 9 | juneau
# Processing Record 34 of Set 9 | majholi
# Processing Record 35 of Set 9 | vao
# Processing Record 36 of Set 9 | san jose
# Processing Record 37 of Set 9 | lillooet
# Processing Record 38 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 9 | howard springs
# Processing Record 40 of Set 9 | port shepstone
# Processing Record 41 of Set 9 | saldanha
# Processing Record 42 of Set 9 | marion
# Processing Record 43 of Set 9 | tomatlan
# Processing Record 44 of Set 9 | kalevala
# Processing Record 45 of Set 9 | calabozo
# Processing Record 46 of Set 9 | kota kinabalu
# Processing Record 47 of Set 9 | kruisfontein
# Processing Record 48 of Set 9 | lebu
# Processing Record 49 of Set 9 | hofn
# Processing Record 50 of Set 9 | sterling
# Processing Record 1 of Set 10 | yulara
# Processing Record 2 of Set 10 | xai-xai
# Processing Record 3 of Set 10 | necochea
# Processing Record 4 of Set 10 | floro
# Processing Record 5 of Set 10 | basi
# Processing Record 6 of Set 10 | xining
# Processing Record 7 of Set 10 | soskovo
# Processing Record 8 of Set 10 | boguchany
# Processing Record 9 of Set 10 | lahad datu
# Processing Record 10 of Set 10 | sisimiut
# Processing Record 11 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 10 | yumen
# Processing Record 13 of Set 10 | bundaberg
# Processing Record 14 of Set 10 | bose
# Processing Record 15 of Set 10 | vestmannaeyjar
# Processing Record 16 of Set 10 | turtas
# Processing Record 17 of Set 10 | opuwo
# Processing Record 18 of Set 10 | nang rong
# Processing Record 19 of Set 10 | mitu
# Processing Record 20 of Set 10 | puerto colombia
# Processing Record 21 of Set 10 | paracatu
# Processing Record 22 of Set 10 | hervey bay
# Processing Record 23 of Set 10 | jiujiang
# Processing Record 24 of Set 10 | vilhena
# Processing Record 25 of Set 10 | prince rupert
# Processing Record 26 of Set 10 | boden
# Processing Record 27 of Set 10 | kattivakkam
# Processing Record 28 of Set 10 | gravdal
# Processing Record 29 of Set 10 | kloulklubed
# Processing Record 30 of Set 10 | madera
# Processing Record 31 of Set 10 | kemijarvi
# Processing Record 32 of Set 10 | batagay
# Processing Record 33 of Set 10 | xinzhou
# Processing Record 34 of Set 10 | uige
# Processing Record 35 of Set 10 | vila
# Processing Record 36 of Set 10 | pindi gheb
# Processing Record 37 of Set 10 | vieira de leiria
# Processing Record 38 of Set 10 | dali
# Processing Record 39 of Set 10 | puerto madryn
# Processing Record 40 of Set 10 | itarema
# Processing Record 41 of Set 10 | aripuana
# Processing Record 42 of Set 10 | dunedin
# Processing Record 43 of Set 10 | youghal
# Processing Record 44 of Set 10 | ilebo
# Processing Record 45 of Set 10 | hattiesburg
# Processing Record 46 of Set 10 | rodrigues alves
# Processing Record 47 of Set 10 | milingimbi
# City not found. Skipping...
# Processing Record 48 of Set 10 | matara
# Processing Record 49 of Set 10 | fulton
# Processing Record 50 of Set 10 | shingu
# Processing Record 1 of Set 11 | aklavik
# Processing Record 2 of Set 11 | rafaela
# Processing Record 3 of Set 11 | northam
# Processing Record 4 of Set 11 | sakakah
# Processing Record 5 of Set 11 | marawi
# Processing Record 6 of Set 11 | makakilo city
# Processing Record 7 of Set 11 | ostrovnoy
# Processing Record 8 of Set 11 | bosconia
# Processing Record 9 of Set 11 | eyl
# Processing Record 10 of Set 11 | sohagpur
# Processing Record 11 of Set 11 | coruripe
# Processing Record 12 of Set 11 | grimmen
# Processing Record 13 of Set 11 | saint anthony
# Processing Record 14 of Set 11 | praia
# Processing Record 15 of Set 11 | batsfjord
# Processing Record 16 of Set 11 | vilyuysk
# Processing Record 17 of Set 11 | gamba
# Processing Record 18 of Set 11 | waitati
# Processing Record 19 of Set 11 | iqaluit
# Processing Record 20 of Set 11 | fiditi
# Processing Record 21 of Set 11 | schenectady
# Processing Record 22 of Set 11 | samarai
# Processing Record 23 of Set 11 | polson
# Processing Record 24 of Set 11 | divnogorsk
# Processing Record 25 of Set 11 | moose factory
# Processing Record 26 of Set 11 | orlik
# Processing Record 27 of Set 11 | taoudenni
# Processing Record 28 of Set 11 | mancio lima
# Processing Record 29 of Set 11 | januaria
# Processing Record 30 of Set 11 | nouadhibou
# Processing Record 31 of Set 11 | lasa
# Processing Record 32 of Set 11 | nabire
# Processing Record 33 of Set 11 | baruun-urt
# Processing Record 34 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 35 of Set 11 | hargeysa
# Processing Record 36 of Set 11 | ishigaki
# Processing Record 37 of Set 11 | saint pete beach
# Processing Record 38 of Set 11 | beloha
# Processing Record 39 of Set 11 | bac lieu
# Processing Record 40 of Set 11 | villa carlos paz
# Processing Record 41 of Set 11 | jerusalem
# Processing Record 42 of Set 11 | letterkenny
# Processing Record 43 of Set 11 | edgewater
# Processing Record 44 of Set 11 | kitimat
# Processing Record 45 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 46 of Set 11 | khandyga
# Processing Record 47 of Set 11 | gladstone
# Processing Record 48 of Set 11 | kerman
# Processing Record 49 of Set 11 | esmeraldas
# Processing Record 50 of Set 11 | salalah
# Processing Record 1 of Set 12 | atasu
# Processing Record 2 of Set 12 | gasan
# Processing Record 3 of Set 12 | sept-iles
# Processing Record 4 of Set 12 | ardakan
# Processing Record 5 of Set 12 | sergeyevka
# Processing Record 6 of Set 12 | kiunga
# Processing Record 7 of Set 12 | udachnyy
# Processing Record 8 of Set 12 | khowst
# Processing Record 9 of Set 12 | ussel
# Processing Record 10 of Set 12 | ciudad bolivar
# Processing Record 11 of Set 12 | litoral del san juan
# City not found. Skipping...
# Processing Record 12 of Set 12 | peleduy
# Processing Record 13 of Set 12 | lagoa
# Processing Record 14 of Set 12 | kaeo
# Processing Record 15 of Set 12 | marsa matruh
# Processing Record 16 of Set 12 | paytug
# City not found. Skipping...
# Processing Record 17 of Set 12 | touros
# Processing Record 18 of Set 12 | victor harbor
# Processing Record 19 of Set 12 | glens falls
# Processing Record 20 of Set 12 | chapais
# Processing Record 21 of Set 12 | gwadar
# Processing Record 22 of Set 12 | jelenia gora
# Processing Record 23 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 12 | puerto carreno
# Processing Record 25 of Set 12 | catuday
# Processing Record 26 of Set 12 | ciulnita
# Processing Record 27 of Set 12 | ixtapa
# Processing Record 28 of Set 12 | dwarka
# Processing Record 29 of Set 12 | khash
# Processing Record 30 of Set 12 | kaa-khem
# Processing Record 31 of Set 12 | mackenzie
# Processing Record 32 of Set 12 | binzhou
# Processing Record 33 of Set 12 | uray
# Processing Record 34 of Set 12 | mogadishu
# Processing Record 35 of Set 12 | nekhayevskiy
# Processing Record 36 of Set 12 | coahuayana
# Processing Record 37 of Set 12 | sao filipe
# Processing Record 38 of Set 12 | havre-saint-pierre
# Processing Record 39 of Set 12 | dubrovka
# Processing Record 40 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 12 | shakawe
# Processing Record 42 of Set 12 | xapuri
# Processing Record 43 of Set 12 | roma
# Processing Record 44 of Set 12 | winton
# Processing Record 45 of Set 12 | otavi
# Processing Record 46 of Set 12 | palauig
# Processing Record 47 of Set 12 | san jeronimo
# Processing Record 48 of Set 12 | deputatskiy
# Processing Record 49 of Set 12 | saint-pierre
# Processing Record 50 of Set 12 | mazatlan
# Processing Record 1 of Set 13 | mwaya
# Processing Record 2 of Set 13 | barbate
# Processing Record 3 of Set 13 | eureka
# Processing Record 4 of Set 13 | sidi bu zayd
# City not found. Skipping...
# Processing Record 5 of Set 13 | san rafael del sur
# Processing Record 6 of Set 13 | taft
# Processing Record 7 of Set 13 | la palma
# Processing Record 8 of Set 13 | amapa
# Processing Record 9 of Set 13 | peterborough
# Processing Record 10 of Set 13 | bariadi
# Processing Record 11 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 13 | niteroi
# Processing Record 13 of Set 13 | kavaratti
# Processing Record 14 of Set 13 | praia da vitoria
# Processing Record 15 of Set 13 | linxia
# Processing Record 16 of Set 13 | tiarei
# Processing Record 17 of Set 13 | alekseyevsk
# Processing Record 18 of Set 13 | gat
# Processing Record 19 of Set 13 | parabel
# Processing Record 20 of Set 13 | griffith
# Processing Record 21 of Set 13 | olafsvik
# Processing Record 22 of Set 13 | kailua
# Processing Record 23 of Set 13 | iwanai
# Processing Record 24 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 13 | tecoanapa
# Processing Record 26 of Set 13 | nome
# Processing Record 27 of Set 13 | partizanskoye
# Processing Record 28 of Set 13 | putai
# Processing Record 29 of Set 13 | fort nelson
# Processing Record 30 of Set 13 | riyadh
# Processing Record 31 of Set 13 | senno
# Processing Record 32 of Set 13 | vrangel
# Processing Record 33 of Set 13 | kargasok
# Processing Record 34 of Set 13 | yatou
# Processing Record 35 of Set 13 | anzio
# Processing Record 36 of Set 13 | constitucion
# Processing Record 37 of Set 13 | jabinyanah
# Processing Record 38 of Set 13 | babstovo
# Processing Record 39 of Set 13 | rebrikha
# Processing Record 40 of Set 13 | inhambane
# Processing Record 41 of Set 13 | kenai
# Processing Record 42 of Set 13 | key west
# Processing Record 43 of Set 13 | paamiut
# Processing Record 44 of Set 13 | berlevag
# Processing Record 45 of Set 13 | thomaston
# Processing Record 46 of Set 13 | sanming
# Processing Record 47 of Set 13 | mosalsk
# Processing Record 48 of Set 13 | guiyang
# Processing Record 49 of Set 13 | el mante
# Processing Record 50 of Set 13 | nizhniy lomov
# Processing Record 1 of Set 14 | raudeberg
# Processing Record 2 of Set 14 | rozhdestveno
# Processing Record 3 of Set 14 | mollendo
# Processing Record 4 of Set 14 | mut
# Processing Record 5 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 6 of Set 14 | gol
# Processing Record 7 of Set 14 | orodara
# Processing Record 8 of Set 14 | maragogi
# Processing Record 9 of Set 14 | alice springs
# Processing Record 10 of Set 14 | hammerfest
# Processing Record 11 of Set 14 | chicama
# Processing Record 12 of Set 14 | bentiu
# Processing Record 13 of Set 14 | elk river
# Processing Record 14 of Set 14 | seoul
# Processing Record 15 of Set 14 | kirkenes
# Processing Record 16 of Set 14 | gambela
# Processing Record 17 of Set 14 | nelson bay
# Processing Record 18 of Set 14 | fernley
# Processing Record 19 of Set 14 | fort walton beach
# Processing Record 20 of Set 14 | verkhnevilyuysk
# Processing Record 21 of Set 14 | winnemucca
# Processing Record 22 of Set 14 | washougal
# Processing Record 23 of Set 14 | barcarena
# Processing Record 24 of Set 14 | bud
# Processing Record 25 of Set 14 | sitia
# Processing Record 26 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 14 | lahaina
# Processing Record 28 of Set 14 | clyde
# Processing Record 29 of Set 14 | yerbogachen
# Processing Record 30 of Set 14 | taquaritinga do norte
# Processing Record 31 of Set 14 | oktyabrskiy
# Processing Record 32 of Set 14 | mbeya
# Processing Record 33 of Set 14 | karlskrona
# Processing Record 34 of Set 14 | bandar
# Processing Record 35 of Set 14 | hay river
# Processing Record 36 of Set 14 | belyy yar
# Processing Record 37 of Set 14 | esna
# Processing Record 38 of Set 14 | buta
# Processing Record 39 of Set 14 | karachi
# Processing Record 40 of Set 14 | san cristobal
# Processing Record 41 of Set 14 | maracaibo
# Processing Record 42 of Set 14 | goderich
# Processing Record 43 of Set 14 | delvada
# Processing Record 44 of Set 14 | hirara
# Processing Record 45 of Set 14 | daru
# Processing Record 46 of Set 14 | san rafael
# Processing Record 47 of Set 14 | sesvete
# Processing Record 48 of Set 14 | padang
# Processing Record 49 of Set 14 | bella union
# Processing Record 50 of Set 14 | upanema
# Processing Record 1 of Set 15 | kirakira
# Processing Record 2 of Set 15 | suntar
# Processing Record 3 of Set 15 | hyderabad
# Processing Record 4 of Set 15 | grand gaube
# Processing Record 5 of Set 15 | boralday
# Processing Record 6 of Set 15 | pasinler
# Processing Record 7 of Set 15 | noyabrsk
# Processing Record 8 of Set 15 | toyooka
# Processing Record 9 of Set 15 | funadhoo
# Processing Record 10 of Set 15 | marabba
# Processing Record 11 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 15 | koumac
# Processing Record 13 of Set 15 | dongsheng
# Processing Record 14 of Set 15 | minsk
# Processing Record 15 of Set 15 | norfolk
# Processing Record 16 of Set 15 | morococha
# Processing Record 17 of Set 15 | kopavogur
# Processing Record 18 of Set 15 | san antonio
# Processing Record 19 of Set 15 | north platte
# Processing Record 20 of Set 15 | lukow
# Processing Record 21 of Set 15 | labuhan
# Processing Record 22 of Set 15 | tinaquillo
# Processing Record 23 of Set 15 | channel-port aux basques
# Processing Record 24 of Set 15 | shimanovsk
# Processing Record 25 of Set 15 | marquette
# Processing Record 26 of Set 15 | port-gentil
# Processing Record 27 of Set 15 | hambantota
# Processing Record 28 of Set 15 | lucea
# Processing Record 29 of Set 15 | ust-omchug
# Processing Record 30 of Set 15 | arlit
# Processing Record 31 of Set 15 | malvern
# Processing Record 32 of Set 15 | simpang
# Processing Record 33 of Set 15 | mayo
# Processing Record 34 of Set 15 | eirunepe
# Processing Record 35 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 15 | rovaniemi
# Processing Record 37 of Set 15 | kingaroy
# Processing Record 38 of Set 15 | baker
# Processing Record 39 of Set 15 | camana
# Processing Record 40 of Set 15 | sorong
# Processing Record 41 of Set 15 | lander
# Processing Record 42 of Set 15 | santa cruz cabralia
# Processing Record 43 of Set 15 | kyshtovka
# Processing Record 44 of Set 15 | sabang
# Processing Record 45 of Set 15 | bay roberts
# Processing Record 46 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 47 of Set 15 | bria
# Processing Record 48 of Set 15 | strangnas
# Processing Record 49 of Set 15 | sibolga
# Processing Record 50 of Set 15 | mae hong son
# Processing Record 1 of Set 16 | yebaishou
# Processing Record 2 of Set 16 | kukmor
# Processing Record 3 of Set 16 | bubaque
# Processing Record 4 of Set 16 | mirganj
# Processing Record 5 of Set 16 | gritsovskiy
# Processing Record 6 of Set 16 | makat
# Processing Record 7 of Set 16 | menongue
# Processing Record 8 of Set 16 | san juan de colon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Ponta Delgada      PT  37.7333  -25.6667     68.72        83          40
# 1     Georgetown      MY   5.4112  100.3354     87.73        80          40
# 2         Hobart      AU -42.8794  147.3294     67.26        46          40
# 3         Silale      LT  55.4906   22.1814     59.79        79          96
# 4       Luderitz      NA -26.6481   15.1594     56.66        54           0
# 5     Deniliquin      AU -35.5333  144.9667     64.00        38           0
# 6        Ushuaia      AR -54.8000  -68.3000     37.06        75          75
# 7        Mataura      NZ -46.1927  168.8643     50.49        97         100
# 8     Lavrentiya      RU  65.5833 -171.0000     46.26        71          72
# 9   Krasnoselkup      RU  65.7000   82.4667     64.06        59          35
#
#    Wind Speed Current Description
# 0        5.75    scattered clouds
# 1        8.05    scattered clouds
# 2        8.01    scattered clouds
# 3        4.94     overcast clouds
# 4        7.00           clear sky
# 5       12.28           clear sky
# 6       39.12          light rain
# 7        8.01     overcast clouds
# 8        6.02       broken clouds
# 9       14.05    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
